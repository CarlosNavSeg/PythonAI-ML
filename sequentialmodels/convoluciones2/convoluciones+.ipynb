# %%
import os
import numpy
import tensorflow as tf

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
(x_train,y_train),(x_test,y_test)=tf.keras.datasets.mnist.load_data('/content/drive/MyDrive/PIA23-24/tema3/convoluciones2/mnist(1).npz')

# %%
from google.colab import drive
drive.mount('/drive')

# %%
class mycallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if (logs.get('accuracy') > 0.998):
      print('Cancelling Training')
      self.model_stop_training= True

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_train= x_train / 255.0
x_test= x_test / 255.0

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64,(3,3),activation='relu', input_shape=(28,28,1)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64,(3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(10,activation='softmax')
])

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics='accuracy')

# %%
model.fit(x_train,y_train,epochs=2, callbacks=[mycallback()])
# Out:
# Epoch 1/2
# 1875/1875 [==============================] - 53s 28ms/step - loss: 0.1223 - accuracy: 0.9625
# Epoch 2/2
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0406 - accuracy: 0.9875
